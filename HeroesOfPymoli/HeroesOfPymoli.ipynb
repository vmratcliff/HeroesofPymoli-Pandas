# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# # Player Count
# - Display the total number of players

# %%
players_count = len(purchase_data["SN"].unique())
summary_table = pd.DataFrame({"Total Players": [players_count]})
summary_table
# Out:
#    Total Players
# 0            576

# %% [markdown]
# # Purchasing Analysis (Total)
# - Run basic calculations to obtain number of unique items, average price, etc.
# - Create a summary data frame to hold the results
# - Optional: give the displayed data cleaner formatting
# - Display the summary data frame

# %%
unique_items = len(purchase_data["Item ID"].unique())
average_price = purchase_data["Price"].mean()
num_purchases = purchase_data["Purchase ID"].count()
total_revenue = purchase_data["Price"].sum()

summary_table = pd.DataFrame({"Number of Unique Items": [unique_items],
                              "Average Price": [average_price,],
                              "Number of Purchases": [num_purchases],
                              "Total Revenue": [total_revenue]})

summary_table.style.format({'Average Price':"${:,.2f}",
                         'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7821033e_5a52_11ea_97cf_dca90499ab37" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7821033e_5a52_11ea_97cf_dca90499ab37level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7821033e_5a52_11ea_97cf_dca90499ab37row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_7821033e_5a52_11ea_97cf_dca90499ab37row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_7821033e_5a52_11ea_97cf_dca90499ab37row0_col2" class="data row0 col2" >780</td>
# ...

# %%
purchase_data["Item ID"].value_counts()
# Out:
# 178    12
# 82      9
# 108     9
# 145     9
# 92      8
#        ..
# 42      1
# 118     1
# 104     1
# 27      1
# 51      1
# Name: Item ID, Length: 183, dtype: int64

# %%
purchase_data.loc[purchase_data['Item Name'] == 'Final Critic']
# Out:
#      Purchase ID            SN  Age  Gender  Item ID     Item Name  Price
# 2              2    Ithergue48   24    Male       92  Final Critic   4.88
# 99            99  Haisrisuir60   23    Male      101  Final Critic   4.19
# 252          252      Tyaelo67   39    Male       92  Final Critic   4.88
# 273          273      Phyali88   15  Female       92  Final Critic   4.88
# 277          277    Ennalmol65   24    Male       92  Final Critic   4.88
# 411          411      Lisico81   10    Male      101  Final Critic   4.19
# 536          536   Siallylis44   20    Male      101  Final Critic   4.19
# 712          712     Lisilsa62   25    Male       92  Final Critic   4.88
# 722          722      Ilarin91   22    Male       92  Final Critic   4.88
# 767          767       Ilmol66    8  Female       92  Final Critic   4.88
# 768          768  Assassasta79   38    Male       92  Final Critic   4.88
# 774          774    Jiskjask80   11    Male      101  Final Critic   4.19
# ...

# %%
purchase_data["Item Name"].value_counts()
# Out:
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Nirvana                                          9
# Persuasion                                       9
# Extraction, Quickblade Of Trembling Hands        9
#                                                 ..
# The Decapitator                                  1
# Ghost Reaver, Longsword of Magic                 1
# Endbringer                                       1
# Riddle, Tribute of Ended Dreams                  1
# Exiled Mithril Longsword                         1
# Name: Item Name, Length: 179, dtype: int64

# %% [markdown]
# # Gender Demographics
# - Percentage and Count of Male Players
# - Percentage and Count of Female Players
# - Percentage and Count of Other / Non-Disclosed

# %%
gender = purchase_data[["SN", "Gender"]]
gender = gender.drop_duplicates()
gender_count = gender["Gender"].value_counts()

total_count_gender = gender_count.sum()
percentage_gender = gender_count / total_count_gender

gender_df = pd.DataFrame({"Total Count": gender_count,
                         "Percentage of Players": percentage_gender})
gender_df.sort_values(["Total Count"], ascending = False).style.format({'Percentage of Players': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37row0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_7d62fa3c_5a52_11ea_97cf_dca90499ab37row1_col0" class="data row1 col0" >81</td>
# ...

# %% [markdown]
# # Purchasing Analysis (Gender)
#
# - Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
# - Create a summary data frame to hold the results
# - Optional: give the displayed data cleaner formatting
# - Display the summary data frame

# %%
purchase_count = purchase_data.groupby("Gender")["Item Name"].count()
avg_purchase_price = purchase_data.groupby("Gender")["Price"].mean()
total_purchase_value = purchase_data.groupby("Gender")["Price"].sum()
avg_total_purchase = total_purchase_value/gender_count

purchase_df = pd.DataFrame({"Purchase Count": purchase_count, 
                            "Average Purchase Price": avg_purchase_price,
                            "Total Purchase Value": total_purchase_value,
                           "Average Total Purchase per Person": avg_total_purchase})

purchase_df.style.format({'Average Purchase Price':"${:,.2f}",
                         'Total Purchase Value': '${:,.2f}',
                         'Average Total Purchase per Person': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7e7027e2_5a52_11ea_97cf_dca90499ab37" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7e7027e2_5a52_11ea_97cf_dca90499ab37level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_7e7027e2_5a52_11ea_97cf_dca90499ab37row0_col0" class="data row0 col0" >113</td>
# ...

# %% [markdown]
# # Age Demographics
# - Establish bins for ages
# - Categorize the existing players using the age bins. Hint: use pd.cut()
# - Calculate the numbers and percentages by age group
# - Create a summary data frame to hold the results
# - Optional: round the percentage column to two decimal points
# - Display Age Demographics Table

# %%
age_df = purchase_data[["SN", "Age"]]
age_df = age_df.drop_duplicates()

bins = [-1, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100000]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

age_df['Age Group'] = pd.cut(age_df['Age'], bins, labels=group_names)

# %%
age_count = age_df['Age Group'].value_counts()
age_percentage = age_count / players_count

# %%
age_df = pd.DataFrame({'Total Count': age_count, 'Percentage of Players': age_percentage})
age_df.sort_index().style.format({'Percentage of Players': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_8055510e_5a52_11ea_97cf_dca90499ab37" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8055510e_5a52_11ea_97cf_dca90499ab37level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_8055510e_5a52_11ea_97cf_dca90499ab37row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_8055510e_5a52_11ea_97cf_dca90499ab37row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_8055510e_5a52_11ea_97cf_dca90499ab37level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_8055510e_5a52_11ea_97cf_dca90499ab37row1_col0" class="data row1 col0" >22</td>
# ...

# %% [markdown]
# # Purchasing Analysis (Age)
# - Bin the purchase_data data frame by age
# - Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
# - Create a summary data frame to hold the results
# - Optional: give the displayed data cleaner formatting
# - Display the summary data frame

# %%
purchase_data["Age Group"] = pd.cut(purchase_data["Age"], bins, labels= group_names)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
age_purchase_df = purchase_data.groupby("Age Group")

age_purchase_count = age_purchase_df["Purchase ID"].count()
avg_price = age_purchase_df["Price"].mean()
total_per_person = age_purchase_df["Price"].sum()
avg_total_pp = total_per_person/age_count

age_purchase_df = pd.DataFrame({'Purchase Count': age_purchase_count.map('{:,}'.format),
                   'Average Purchase Price': avg_price.map('${:,.2f}'.format),
                   'Total Purchase Value': total_per_person.map('${:,.2f}'.format),
                   'Avg Total Purchase per Person': avg_total_pp.map('${:,.2f}'.format)})
                                
age_purchase_df
# Out:
#       Purchase Count Average Purchase Price Total Purchase Value  \
# <10               23                  $3.35               $77.13
# 10-14             28                  $2.96               $82.78
# 15-19            136                  $3.04              $412.89
# 20-24            365                  $3.05            $1,114.06
# 25-29            101                  $2.90              $293.00
# 30-34             73                  $2.93              $214.00
# 35-39             41                  $3.60              $147.67
# 40+               13                  $2.94               $38.24
#
#       Avg Total Purchase per Person
# <10                           $4.54
# 10-14                         $3.76
# 15-19                         $3.86
# 20-24                         $4.32
# 25-29                         $3.81
# 30-34                         $4.12
# 35-39                         $4.76
# 40+                           $3.19

# %% [markdown]
# # Top Spenders
# - Run basic calculations to obtain the results in the table below
# - Create a summary data frame to hold the results
# - Sort the total purchase value column in descending order
# - Optional: give the displayed data cleaner formatting
# - Display a preview of the summary data frame

# %%
spenders = purchase_data.loc[:, ['SN', 'Price']]
spenders = spenders.groupby('SN')

spenders_df = spenders.count()
spenders_df = spenders_df.rename(columns={'Price': 'Purchase Count'})
spenders_df['Average Purchase Price'] = spenders.mean()
spenders_df['Total Purchase Value'] = spenders.sum()

spenders_df = spenders_df.sort_values(["Total Purchase Value"], ascending=False)
spenders_df['Average Purchase Price'] = spenders_df['Average Purchase Price'].map('${:,.2f}'.format)
spenders_df['Total Purchase Value'] = spenders_df['Total Purchase Value'].map('${:,.2f}'.format)

spenders_df.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# # Most Popular Items
# - Retrieve the Item ID, Item Name, and Item Price columns
# - Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
# - Create a summary data frame to hold the results
# - Sort the purchase count column in descending order
# - Optional: give the displayed data cleaner formatting
# - Display a preview of the summary data frame

# %%
pop_items = purchase_data.loc[:, ['Item ID', 'Item Name', 'Price']]
pop_items = pop_items.rename(columns={'Price': 'Purchase Count'})
pop_items_grp = pop_items.groupby(['Item ID', 'Item Name'])

pop_items_df = pop_items_grp.count()
pop_items_df['Item Price'] = pop_items_grp.mean()
pop_items_df['Total Purchase Value'] = pop_items_df['Item Price']*pop_items_df['Purchase Count']

pop_items_df =  pop_items_df.sort_values(["Purchase Count"], ascending=False)
pop_items_df['Item Price'] = pop_items_df['Item Price'].map('${:,.2f}'.format)
pop_items_df['Total Purchase Value'] = pop_items_df['Total Purchase Value'].map('${:,.2f}'.format)

pop_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# # Most Profitable Items
# - Sort the above table by total purchase value in descending order
# - Optional: give the displayed data cleaner formatting
# - Display a preview of the data frame

# %%
profit_items = purchase_data.loc[:, ['Item ID', 'Item Name', 'Price']]
profit_items = profit_items.rename(columns={'Price': 'Purchase Count'})
profit_items_grp = profit_items.groupby(['Item ID', 'Item Name'])

profit_items_df = profit_items_grp.count()
profit_items_df['Item Price'] = profit_items_grp.mean()
profit_items_df['Total Purchase Value'] = profit_items_df['Item Price']*profit_items_df['Purchase Count']

profit_items_df =  profit_items_df.sort_values(["Total Purchase Value"], ascending=False)
profit_items_df['Item Price'] = profit_items_df['Item Price'].map('${:,.2f}'.format)
profit_items_df['Total Purchase Value'] = profit_items_df['Total Purchase Value'].map('${:,.2f}'.format)

profit_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
